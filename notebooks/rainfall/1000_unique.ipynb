# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')

# %%
from autoplan.trainer import ClassifierTrainer, option_combinations
from autoplan.dataset import PrelabeledDataset, build_synthetic_dataset, TrainVal
from autoplan.generator import ProgramGenerator
from autoplan.vis import plot_accuracy, plot_cm, plot_loss
from autoplan.token import TokenType, PyretTokenizer, OCamlTokenizer
from scripts.rainfall_ingest import ingest_dataset

from grammars.rainfall.ocaml import Program
from grammars.rainfall.labels import GeneralRainfallLabels

from tqdm import tqdm_notebook as tqdm
import pandas as pd
import torch
import os
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt
import pickle
# import seaborn as sns

# device = torch.device('cpu')
device = torch.device('cuda:3')
REPO_DIR = os.path.expanduser('~/autoplan')
path = os.path.expanduser('~/autoplan/data/pickle')

# %%
dataset_name = 'T1'
student_dataset = ingest_dataset(dataset_name)
# Out:
# Skipped 16 programs

# %%
sample_size = [
    ('N', [1000])
]

# k is the number of datasets generated for each sample size
k = 5

unique_datasets = [
    (opts, build_synthetic_dataset(
                GeneralRainfallLabels,
                tokenizer=OCamlTokenizer(),
                generator=ProgramGenerator(grammar=Program(), adaptive=True),
                vocab_index=student_dataset.vocab_index,
                unique=True,
                **opts))
    for opts in option_combinations(sample_size)
        for i in range(k)
]

duplicate_datasets = [
    (opts, build_synthetic_dataset(
                GeneralRainfallLabels,
                tokenizer=OCamlTokenizer(),
                generator=ProgramGenerator(grammar=Program(), adaptive=True),
                vocab_index=student_dataset.vocab_index,
                unique=False,
                **opts))
    for opts in option_combinations(sample_size)
        for i in range(k)
]
# Out:
# Generating programs...
# Generated 1000 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 1000 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 1000 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 1000 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 1000 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 609 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 636 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 616 unique programs.
# Tokenizing programs...
# Building dataset metadata...
# Generating programs...
# Generated 612 unique programs.
# Tokenizing programs...
# Building dataset metadata...

# %%
model_options = [
    ('dataset', unique_datasets),
    ('model', [nn.GRU, nn.LSTM]),
    ('hidden_size', [128, 512, 2048]),
    ('embedding_size', [128, 512, 2048]),
]

all_evals = [
    (opts, ClassifierTrainer.crossval(opts['dataset'][1], epochs=100, device=device,
                                      split=TrainVal(opts['dataset'][1], student_dataset), 
                                      model_opts={k: v for k, v in opts.items() if k != 'dataset'}))
    for opts in tqdm(option_combinations(model_options))
]
# Out:
# HBox(children=(IntProgress(value=0, max=90), HTML(value='')))

# %%
sorted([{
    'params': k, 
    'accuracy': np.mean(v['accuracy'])
} for k, v in all_evals], key=lambda t: -t['accuracy'])
# Out:
# [{'params': {'embedding_size': 512,
#    'hidden_size': 512,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fccd56016a0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0790, 0.8890]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.5, True), (0.5, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'fail_message': [(0.20000000298023224, '"invalid input (ocaml needed this wildcard for some reason)"'), (0.20000000298023224, '"The list does not have final value -999"'), (0.20000000298023224, '"No data of interest"'), (0.20000000298023224, '"Please input a list with at least one non-negative value before the first instance of -999."'), (0.20000000298023224, '"cannot divide by zero!!"')], 'separate_sentinel_check': [(0.6666666865348816, True), (0.3333333432674408, False)], 'check_div_by_zero': [(0.75, True), (0.25, False)], 'check_counter_val': [(0.6666666865348816, True), (0.3333333432674408, False)], 'helpers_in_body': [(0.625, True), (0.375, False)], 'anonymous_helpers': [(0.6000000238418579, True), (0.40000003576278687, False)], 'raises_failwith': [(0.5833333134651184, True), (0.4166666865348816, False)], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'helper_in_body': [(0.5625, True), (0.4374999701976776, False)], 'gt_zero': [(0.5714285373687744, True), (0.4285714328289032, False)], 'recurse_empty_list': [(0.5833333134651184, True), (0.4166666865348816, False)], 'check_positive_head': [(0.5769230723381042, True), (0.42307695746421814, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'fail_message': 5, 'separate_sentinel_check': 6, 'check_div_by_zero': 7, 'check_counter_val': 8, 'helpers_in_body': 9, 'anonymous_helpers': 10, 'raises_failwith': 11, 'rainfall_body_specs': 12, 'recursion_strategy': 13, 'check_empty_list': 14, 'helper_in_body': 15, 'gt_zero': 16, 'recurse_empty_list': 17, 'check_positive_head': 18}))},
#   'accuracy': 0.8888888888888888},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fccce23f780>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0810, 0.8870]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6363636255264282, True), (0.3636363744735718, False)], 'gt_zero': [(0.6666666865348816, True), (0.3333333432674408, False)], 'separate_sentinel_check': [(0.6428571343421936, True), (0.357142835855484, False)], 'recurse_empty_list': [(0.625, True), (0.375, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6233766078948975, True), (0.37662339210510254, False)], 'helpers_in_body': [(0.6282051205635071, True), (0.37179484963417053, False)], 'anonymous_helpers': [(0.6329113841056824, True), (0.3670886158943176, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8888888888888888},
#  {'params': {'embedding_size': 512,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8888888888888888},
#  {'params': {'embedding_size': 2048,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc388470>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0970, 0.8710]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.75, True), (0.25, False)], 'raises_failwith': [(0.75, True), (0.25, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.625, True), (0.375, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.6071428656578064, True), (0.3928571343421936, False)], 'recurse_empty_list': [(0.6206896901130676, True), (0.37931033968925476, False)], 'check_positive_head': [(0.6129032373428345, True), (0.3870967626571655, False)], 'check_counter_val': [(0.625, True), (0.375, False)], 'helpers_in_body': [(0.6307692527770996, True), (0.3692307770252228, False)], 'anonymous_helpers': [(0.6268656849861145, True), (0.3731343448162079, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8888888888888888},
#  {'params': {'embedding_size': 512,
#    'hidden_size': 512,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc388470>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0970, 0.8710]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.75, True), (0.25, False)], 'raises_failwith': [(0.75, True), (0.25, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.625, True), (0.375, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.6071428656578064, True), (0.3928571343421936, False)], 'recurse_empty_list': [(0.6206896901130676, True), (0.37931033968925476, False)], 'check_positive_head': [(0.6129032373428345, True), (0.3870967626571655, False)], 'check_counter_val': [(0.625, True), (0.375, False)], 'helpers_in_body': [(0.6307692527770996, True), (0.3692307770252228, False)], 'anonymous_helpers': [(0.6268656849861145, True), (0.3731343448162079, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8888888888888888},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.GRU,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fccce23f780>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0810, 0.8870]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6363636255264282, True), (0.3636363744735718, False)], 'gt_zero': [(0.6666666865348816, True), (0.3333333432674408, False)], 'separate_sentinel_check': [(0.6428571343421936, True), (0.357142835855484, False)], 'recurse_empty_list': [(0.625, True), (0.375, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6233766078948975, True), (0.37662339210510254, False)], 'helpers_in_body': [(0.6282051205635071, True), (0.37179484963417053, False)], 'anonymous_helpers': [(0.6329113841056824, True), (0.3670886158943176, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8666666666666667},
#  {'params': {'embedding_size': 2048,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8666666666666667},
#  {'params': {'embedding_size': 512,
#    'hidden_size': 512,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8666666666666667},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.GRU,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc388470>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0970, 0.8710]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.75, True), (0.25, False)], 'raises_failwith': [(0.75, True), (0.25, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.625, True), (0.375, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.6071428656578064, True), (0.3928571343421936, False)], 'recurse_empty_list': [(0.6206896901130676, True), (0.37931033968925476, False)], 'check_positive_head': [(0.6129032373428345, True), (0.3870967626571655, False)], 'check_counter_val': [(0.625, True), (0.375, False)], 'helpers_in_body': [(0.6307692527770996, True), (0.3692307770252228, False)], 'anonymous_helpers': [(0.6268656849861145, True), (0.3731343448162079, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8666666666666667},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccce51208>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0690, 0.8990]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.5833333134651184, True), (0.4166666865348816, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.5999999642372131, True), (0.3999999761581421, False)], 'recurse_empty_list': [(0.5882353186607361, True), (0.4117647111415863, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6276595592498779, True), (0.3723404109477997, False)], 'helpers_in_body': [(0.6269841194152832, True), (0.3730158805847168, False)], 'anonymous_helpers': [(0.6279683113098145, True), (0.37203165888786316, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8666666666666667},
#  {'params': {'embedding_size': 2048,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fccd56016a0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0790, 0.8890]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.5, True), (0.5, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'fail_message': [(0.20000000298023224, '"invalid input (ocaml needed this wildcard for some reason)"'), (0.20000000298023224, '"The list does not have final value -999"'), (0.20000000298023224, '"No data of interest"'), (0.20000000298023224, '"Please input a list with at least one non-negative value before the first instance of -999."'), (0.20000000298023224, '"cannot divide by zero!!"')], 'separate_sentinel_check': [(0.6666666865348816, True), (0.3333333432674408, False)], 'check_div_by_zero': [(0.75, True), (0.25, False)], 'check_counter_val': [(0.6666666865348816, True), (0.3333333432674408, False)], 'helpers_in_body': [(0.625, True), (0.375, False)], 'anonymous_helpers': [(0.6000000238418579, True), (0.40000003576278687, False)], 'raises_failwith': [(0.5833333134651184, True), (0.4166666865348816, False)], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'helper_in_body': [(0.5625, True), (0.4374999701976776, False)], 'gt_zero': [(0.5714285373687744, True), (0.4285714328289032, False)], 'recurse_empty_list': [(0.5833333134651184, True), (0.4166666865348816, False)], 'check_positive_head': [(0.5769230723381042, True), (0.42307695746421814, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'fail_message': 5, 'separate_sentinel_check': 6, 'check_div_by_zero': 7, 'check_counter_val': 8, 'helpers_in_body': 9, 'anonymous_helpers': 10, 'raises_failwith': 11, 'rainfall_body_specs': 12, 'recursion_strategy': 13, 'check_empty_list': 14, 'helper_in_body': 15, 'gt_zero': 16, 'recurse_empty_list': 17, 'check_positive_head': 18}))},
#   'accuracy': 0.8444444444444444},
#  {'params': {'embedding_size': 2048,
#    'hidden_size': 2048,
#    'model': torch.nn.modules.rnn.GRU,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8444444444444444},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 128,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.8444444444444444},
#  {'params': {'embedding_size': 512,
#    'hidden_size': 2048,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
# ...
#   'accuracy': 0.7333333333333333},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 2048,
#    'model': torch.nn.modules.rnn.GRU,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccce51208>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0690, 0.8990]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.5833333134651184, True), (0.4166666865348816, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.5999999642372131, True), (0.3999999761581421, False)], 'recurse_empty_list': [(0.5882353186607361, True), (0.4117647111415863, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6276595592498779, True), (0.3723404109477997, False)], 'helpers_in_body': [(0.6269841194152832, True), (0.3730158805847168, False)], 'anonymous_helpers': [(0.6279683113098145, True), (0.37203165888786316, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.7333333333333333},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 2048,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fccce23f780>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0810, 0.8870]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6363636255264282, True), (0.3636363744735718, False)], 'gt_zero': [(0.6666666865348816, True), (0.3333333432674408, False)], 'separate_sentinel_check': [(0.6428571343421936, True), (0.357142835855484, False)], 'recurse_empty_list': [(0.625, True), (0.375, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6233766078948975, True), (0.37662339210510254, False)], 'helpers_in_body': [(0.6282051205635071, True), (0.37179484963417053, False)], 'anonymous_helpers': [(0.6329113841056824, True), (0.3670886158943176, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.7111111111111111},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 512,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccc45e5c0>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0780, 0.8900]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.6875000596046448, True), (0.3125000298023224, False)], 'gt_zero': [(0.7058823704719543, True), (0.29411765933036804, False)], 'separate_sentinel_check': [(0.7222222089767456, True), (0.277777761220932, False)], 'recurse_empty_list': [(0.7000000476837158, True), (0.30000001192092896, False)], 'check_positive_head': [(0.6818181872367859, True), (0.3181818425655365, False)], 'check_counter_val': [(0.6270270347595215, True), (0.3729729950428009, False)], 'helpers_in_body': [(0.625668466091156, True), (0.3743315637111664, False)], 'anonymous_helpers': [(0.6243385672569275, True), (0.37566137313842773, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.7111111111111111},
#  {'params': {'embedding_size': 128,
#    'hidden_size': 2048,
#    'model': torch.nn.modules.rnn.LSTM,
#    'dataset': ({'N': 1000},
#     SyntheticDataset(dataset=<autoplan.dataset.ProgramDataset object at 0x7fcccce51208>, vocab_size=63, vocab_index={('LET', ''): 0, ('REC', ''): 1, 'LIDENT': 2, ('LPAREN', ''): 3, ('COLON', ''): 4, ('RPAREN', ''): 5, ('EQUAL', ''): 6, ('MATCH', ''): 7, ('COMMA', ''): 8, ('WITH', ''): 9, ('BAR', ''): 10, ('LBRACKET', ''): 11, ('RBRACKET', ''): 12, ('FLOAT', '0.'): 13, ('MINUSGREATER', ''): 14, 'STRING': 15, ('MINUS', ''): 16, ('FLOAT', '999.'): 17, ('COLONCOLON', ''): 18, ('UNDERSCORE', ''): 19, ('IF', ''): 20, ('INFIXOP0', '>='): 21, ('THEN', ''): 22, ('PLUSDOT', ''): 23, ('FLOAT', '1.'): 24, ('ELSE', ''): 25, ('STAR', ''): 26, ('IN', ''): 27, ('INFIXOP3', '/.'): 28, ('INT', '0'): 29, ('INFIXOP3', '/'): 30, ('INT', '999'): 31, ('GREATER', ''): 32, ('INT', '1'): 33, ('PLUS', ''): 34, ('LESS', ''): 35, ('WHEN', ''): 36, ('INFIXOP0', '!='): 37, ('SEMI', ''): 38, ('INT', '4'): 39, ('INT', '6'): 40, ('INT', '8'): 41, ('INT', '2'): 42, ('INT', '5'): 43, ('INT', '3'): 44, ('FLOAT', '999.0'): 45, ('AMPERAMPER', ''): 46, ('FLOAT', '0.0'): 47, 'UIDENT': 48, ('DOT', ''): 49, ('FUN', ''): 50, ('TRUE', ''): 51, ('FALSE', ''): 52, ('INFIXOP0', '=='): 53, ('INFIXOP0', '<>'): 54, ('INFIXOP3', 'lxor'): 55, ('INFIXOP3', 'lor'): 56, ('PREFIXOP', '~-'): 57, ('QUOTE', ''): 58, ('MINUSDOT', ''): 59, ('INFIXOP0', '<='): 60, ('TRY', ''): 61, 'UNK': 62}, label_set=[<GeneralRainfallLabels.CleanFirst: 0>, <GeneralRainfallLabels.CleanInSC: 1>, <GeneralRainfallLabels.SingleLoop: 2>], class_balance=tensor([0.0320, 0.0690, 0.8990]), choices={'START': [(1.0, None)], 'strategy': [(0.3333333432674408, <GeneralRainfallLabels.SingleLoop: 2>), (0.3333333432674408, <GeneralRainfallLabels.CleanFirst: 0>), (0.3333333432674408, <GeneralRainfallLabels.CleanInSC: 1>)], 'recursion': [(0.5, ''), (0.5, 'rec')], 'uses_annotation': [(0.6666666865348816, True), (0.3333333432674408, False)], '_type': [(0.5, 'int'), (0.5, 'float')], 'helper_in_body': [(0.6666666865348816, True), (0.3333333432674408, False)], 'raises_failwith': [(0.6000000238418579, True), (0.40000003576278687, False)], 'fail_message': [(1.0, '"No rain was collected"')], 'rainfall_body_specs': [(0.5, 'direct_pass'), (0.5, 'recurse')], 'recursion_strategy': [(0.5, 'match'), (0.5, 'let')], 'check_empty_list': [(0.5, '[]'), (0.5, '(0, 0)')], 'check_div_by_zero': [(0.5833333134651184, True), (0.4166666865348816, False)], 'gt_zero': [(0.6153846383094788, True), (0.38461539149284363, False)], 'separate_sentinel_check': [(0.5999999642372131, True), (0.3999999761581421, False)], 'recurse_empty_list': [(0.5882353186607361, True), (0.4117647111415863, False)], 'check_positive_head': [(0.6111111640930176, True), (0.3888888955116272, False)], 'check_counter_val': [(0.6276595592498779, True), (0.3723404109477997, False)], 'helpers_in_body': [(0.6269841194152832, True), (0.3730158805847168, False)], 'anonymous_helpers': [(0.6279683113098145, True), (0.37203165888786316, False)]}, choice_indices={'START': 0, 'strategy': 1, 'recursion': 2, 'uses_annotation': 3, '_type': 4, 'helper_in_body': 5, 'raises_failwith': 6, 'fail_message': 7, 'rainfall_body_specs': 8, 'recursion_strategy': 9, 'check_empty_list': 10, 'check_div_by_zero': 11, 'gt_zero': 12, 'separate_sentinel_check': 13, 'recurse_empty_list': 14, 'check_positive_head': 15, 'check_counter_val': 16, 'helpers_in_body': 17, 'anonymous_helpers': 18}))},
#   'accuracy': 0.7111111111111111}]

# %%
path = os.path.expanduser('~/autoplan/data/pickle_data/1000_unique')
pickle.dump(unique_datasets, open(path, 'wb'))
path = os.path.expanduser('~/autoplan/data/pickle_data/1000_duplicate')
pickle.dump(duplicate_datasets, open(path, 'wb'))

# %%
path = os.path.expanduser('~/autoplan/data/pickle_data/1000_unique_evals')
pickle.dump(all_evals, open(path, 'wb'))

# %%
print(data[0][1]['loss'])
print('='*10)
print(data[0][1]['accuracy'])
