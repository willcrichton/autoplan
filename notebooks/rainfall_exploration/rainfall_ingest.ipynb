# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append('..')

# %%
import pandas as pd
import os

from grammars.rainfall.labels import GeneralRainfallLabels, DetailedRainfallLabels
from autoplan.dataset import build_prelabeled_dataset, PrelabeledDataset
from autoplan.token import OCamlTokenizer, PyretTokenizer, TokenizerError

# %%
REPO_DIR = os.path.expanduser('~/autoplan')
DATA_DIR = f'{REPO_DIR}/data/rainfall/raw'
CODE_DIR = f'{DATA_DIR}/Fall2013-RawData'

def read_coding_csv(name):
    return pd.read_csv(f'{DATA_DIR}/Fall2013Coding{name}.csv', index_col=0, header=None).T

# %%
plan_codes = pd.read_csv(f'{DATA_DIR}/PlanCodes-codes.csv')

def read_and_join_coding(name):
    coding_csv = read_coding_csv(name)

    valid_entries = coding_csv[coding_csv.PlanStructure.notnull()]

    combined_entries = valid_entries.set_index('PlanStructure').join(plan_codes.set_index('Code'))
    
    return combined_entries

# %%
df = read_and_join_coding('T1')
df
# Out:
#        ID School Course    Lang   Time                        Prior NumTests  \
# IP1    10  Brown   cs17      ml     25                       little        7
# IP1    14  Brown   cs17      ml     10                 other course       14
# IP1    15  Brown   cs17      ml     20                         none        3
# IP1    35  Brown   cs17      ml     30            2 years with APCS        7
# IP1    50  Brown   cs17      ml     15                    APCS; CS4        6
# IP1    53  Brown   cs17      ml     30               matlab; python        9
# IP1    61  Brown   cs17      ml     45                          lua        6
# IP1    85  Brown   cs17      ml     25                         APCS        0
# IP1    86  Brown   cs17      ml     30                         none        4
# IP1    99  Brown   cs17      ml      5                  matlab html        3
# IP1   100  Brown   cs17      ml     15                         APCS       10
# IP1   109  Brown   cs17      ml     30           codeacademy python        5
# IP1   119  Brown   cs17      ml   none                           45        5
# IP1   120  Brown   cs17      ml      5                       matlab        4
# IP1   136  Brown   cs17      ml     20                         java        5
# IP1   139  Brown   cs17  racket   7+15  javascript with codeacademy       10
# IP1   142  Brown   cs17  racket    NaN                          NaN        4
# IP1   144  Brown   cs17  racket     10                    self java        4
# IP1   145  Brown   cs17  racket     20                liitle python        3
# IP10  153  Brown   cs17  racket     10                     self bit        0
# IP16  103  Brown   cs17      ml     10                C; javascript        2
# IP27    8  Brown   cs17      ml     60                     year c++        2
# IP3   117  Brown   cs17      ml     30                         APCS        5
# IP33   78  Brown   cs17      ml     13                          c++        0
# IP46   77  Brown   cs17      ml     45                         none        8
# IP5     4  Brown   cs17      ml     30                      HS Java        4
# IP5   127  Brown   cs17      ml     30                         none        7
# IP5   140  Brown   cs17  racket  18+10                       cs0931        4
# IP5   143  Brown   cs17  racket     30                    HS racket        8
# IP5   146  Brown   cs17  racket     30                         none        0
# ...   ...    ...    ...     ...    ...                          ...      ...
# IP6   114  Brown   cs17      ml     25                       matlab        5
# IP6   124  Brown   cs17      ml     30                         java        1
# IP6   141  Brown   cs17  racket     10                         none        3
# IP6   147  Brown   cs17  racket     10                    python HS        3
# IP6   148  Brown   cs17  racket      5                   many years        0
# IP63    3  Brown   cs17      ml    NaN                          NaN        0
# IP64   11  Brown   cs17      ml     10                python;c;java        3
# IP65   18  Brown   cs17      ml     40                3 years; APCS        4
# IP65   23  Brown   cs17      ml     30                         none        0
# IP65   28  Brown   cs17      ml     60                         none        4
# IP65   66  Brown   cs17      ml     10                       python        4
# IP66   22  Brown   cs17      ml    NaN                          NaN        2
# IP67   68  Brown   cs17      ml     20                         none        4
# IP68   73  Brown   cs17      ml    NaN                          NaN        0
# IP69   79  Brown   cs17      ml     10                       python        4
# IP7   149  Brown   cs17  racket      5                         none        4
# IP70   96  Brown   cs17      ml      5                       python        4
# IP71  111  Brown   cs17      ml     20                         none        5
# IP72  113  Brown   cs17      ml    NaN                          NaN        3
# IP73  115  Brown   cs17      ml    NaN                          NaN        5
# IP74  122  Brown   cs17      ml     15                 python; java        6
# IP74  131  Brown   cs17      ml     20                      VB;APCS        5
# IP75  128  Brown   cs17      ml     15                     c++; cs4        4
# IP76  130  Brown   cs17      ml     45                         none        3
# IP8    60  Brown   cs17      ml     30                         none        3
# IP8    98  Brown   cs17      ml     20            self html css php        6
# IP8   150  Brown   cs17  racket     40                           AP        7
# IP8   151  Brown   cs17  racket     10                  codeacademy        0
# IP8   154  Brown   cs17  racket    NaN                          NaN        3
# IP9   152  Brown   cs17  racket  10+20                         none        7
#
#      TestsAccurate TestNegatives? TestEmpty?  ... randomSet  \
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          n  ...         1
# IP1              y              y          n  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         1
# IP1              0              n          n  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          n  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          n  ...         1
# IP1              y              y          y  ...         1
# IP1              y              y          y  ...         0
# IP1              y              n          y  ...         0
# IP1              y              y          y  ...         0
# IP1              y              y          n  ...         0
# IP10             0              n          n  ...         0
# IP16             y              n          n  ...         1
# IP27             1              y          n  ...         1
# IP3              y              y          y  ...         1
# IP33             0              n          n  ...         1
# IP46             y              y          y  ...         1
# IP5              y              y          n  ...         1
# IP5              y              y          y  ...         1
# IP5              y              y          y  ...         0
# IP5              y              y          n  ...         0
# IP5              0              n          n  ...         0
# ...            ...            ...        ...  ...       ...
# IP6              0              y          n  ...         1
# IP6              y              y          n  ...         1
# IP6              y              y          y  ...         0
# IP6              y              y          n  ...         0
# IP6              0              n          n  ...         0
# IP63             0              n          n  ...         1
# IP64             y              n          n  ...         1
# IP65             y              y          y  ...         1
# IP65             0              n          n  ...         1
# IP65             y              y          y  ...         1
# IP65             y              y          n  ...         1
# IP66             y              y          n  ...         1
# IP67             y              y          n  ...         1
# IP68             0              n          n  ...         1
# IP69         noAns              y          y  ...         1
# IP7              y              y          n  ...         0
# IP70             y              y          n  ...         1
# IP71             y              y          y  ...         1
# IP72             y              y          n  ...         1
# IP73             4              y          n  ...         1
# IP74             y              n          y  ...         1
# IP74             y              y          y  ...         1
# IP75             y              y          y  ...         1
# IP76             y              y          y  ...         1
# IP8              y              y          n  ...         1
# IP8              y              y          n  ...         1
# IP8              y              y          n  ...         0
# IP8              0              n          n  ...         0
# IP8              y              y          n  ...         0
# IP9              y              y          y  ...         0
#
#                                                    Note  \
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                raised error if sentinel not in list
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP1                                                 NaN
# IP10                                                NaN
# IP16                                                NaN
# IP27  comment that tried to optimize with 'accelerator'
# IP3                                                 NaN
# IP33                                                NaN
# IP46                                                NaN
# IP5   missed divzero check in base but remembered wi...
# IP5                                                 NaN
# IP5                                                 NaN
# IP5                                                 NaN
# IP5                                                 NaN
# ...                                                 ...
# IP6                                                 NaN
# IP6                                                 NaN
# IP6                                                 NaN
# IP6                                                 NaN
# IP6                                                 NaN
# IP63                                                NaN
# IP64                                                NaN
# IP65                                                NaN
# IP65                                                NaN
# IP65                                                NaN
# IP65  student wrote two solutions (first clean then ...
# IP66                                                NaN
# IP67                                                NaN
# IP68      no indentation--entire program is on one line
# IP69                                                NaN
# IP7                                                 NaN
# IP70                                                NaN
# IP71                                                NaN
# IP72      calling T&N within recursive function for sum
# IP73                     odd indentation - hard to read
# IP74                                                NaN
# IP74                                                NaN
# IP75                                                NaN
# IP76                                                NaN
# IP8                                                 NaN
# IP8                                                 NaN
# IP8                                                 NaN
# IP8                                                 NaN
# IP8                                                 NaN
# IP9                                                 NaN
#
#                                                   show?    CombinedErrors  \
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN          X-G-P;I;
# IP1                                                 NaN            X-G-P;
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN            X-G-P;
# IP1                                                 NaN            X-G-P;
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP1                                                 NaN               NaN
# IP10                                         very tight          X-B;X-B;
# IP16                                                NaN               NaN
# IP27                                                NaN               NaN
# IP3                                                 NaN            X-G-P;
# IP33                                                NaN               NaN
# IP46                                                NaN               NaN
# IP5   clean first written with nested HOF -- differe...            X-G-P;
# IP5                                                 NaN               NaN
# IP5                                                 NaN               NaN
# IP5                                                 NaN               NaN
# IP5                                                 NaN               NaN
# ...                                                 ...               ...
# IP6                                                 NaN               NaN
# IP6                                                 NaN               NaN
# IP6                                                 NaN            X-G-P;
# IP6                                                 NaN               NaN
# IP6                 very small but somehow hard to read               NaN
# IP63                                                NaN               NaN
# IP64                                                NaN               NaN
# IP65                                                NaN               NaN
# IP65                                                NaN               NaN
# IP65                                                NaN               NaN
# IP65                                                NaN               NaN
# IP66                                                NaN              F-G;
# IP67                                                NaN               NaN
# IP68                                                NaN               NaN
# IP69                                                NaN            X-G-P;
# IP7                                        off template  X-B;X-B;X-B;X-B;
# IP70                                                NaN               NaN
# IP71                                                NaN               NaN
# IP72                                                NaN               NaN
# IP73                                                NaN            X-G-P;
# IP74                                                NaN               NaN
# IP74                                                NaN               NaN
# IP75                                                NaN               NaN
# IP76                                                NaN               NaN
# IP8                                                 NaN               NaN
# IP8                                                 NaN               NaN
# IP8                                                 NaN               NaN
# IP8                                                 NaN               NaN
# IP8                                                 NaN               NaN
# IP9                                                 NaN            X-G-P;
#
#      ErrorCount                               Form Detail Category  \
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           2         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           1         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           1         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           1         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP1           0         (N & T & S & C) ; (D -> A)      AccumStyle
# IP10          2                ((T&N);S|(T&N);C);A        T&NFirst
# IP16          0                    (T & S & C) ; A      AccumStyle
# IP27          0            ((T & S) | (T & C)) ; A      CleanInS&C
# IP3           1               D ->(T&N); (S|C) ; A        T&NFirst
# IP33          0                  T ; N ; (S|C) ; A   SentinelFirst
# IP46          0      D -> (T ; N ; D -> (S|C) ; A)   SentinelFirst
# IP5           1              T&N ; D -> (S|C)  ; A        T&NFirst
# IP5           0              T&N ; D -> (S|C)  ; A        T&NFirst
# IP5           0              T&N ; D -> (S|C)  ; A        T&NFirst
# IP5           0              T&N ; D -> (S|C)  ; A        T&NFirst
# IP5           0              T&N ; D -> (S|C)  ; A        T&NFirst
# ...         ...                                ...             ...
# IP6           0                  T&N ; (S|C)  ;  A        T&NFirst
# IP6           0                  T&N ; (S|C)  ;  A        T&NFirst
# IP6           1                  T&N ; (S|C)  ;  A        T&NFirst
# IP6           0                  T&N ; (S|C)  ;  A        T&NFirst
# IP6           0                  T&N ; (S|C)  ;  A        T&NFirst
# IP63          0                (N & T & S & C) ; A      AccumStyle
# IP64          0               (T & S & C) ; D -> A      AccumStyle
# IP65          0      T&N; D -> ((T&N);S|(T&N);C);A        T&NFirst
# IP65          0      T&N; D -> ((T&N);S|(T&N);C);A        T&NFirst
# IP65          0      T&N; D -> ((T&N);S|(T&N);C);A        T&NFirst
# IP65          0      T&N; D -> ((T&N);S|(T&N);C);A        T&NFirst
# IP66          1  (T&N&S) | (T&N&C); D->(T&N&C) ; A      CleanInS&C
# IP67          0             T ; N ; C ; D -> S ; A   SentinelFirst
# IP68          0        (T&N&S) | (T&N&C) ; D-> ; A      CleanInS&C
# IP69          1            D-> (N & T & S & C) ; A      AccumStyle
# IP7           4  (C&T&N); D -> ((S&T&N)|(C&T&N));A      CountFirst
# IP70          0             T ; N ; S ; D -> C ; A   SentinelFirst
# IP71          0               T&N ; C ; D -> S ; A        T&NFirst
# IP72          0   T&N ; C ; D -> T&N ; (T&N Rec S)        T&NFirst
# IP73          1           T -> (T&N&S | T&N&C) ; A      CleanInS&C
# IP74          0   T&N&C ; D -> (T&N&S | T&N&C) ; A      CleanInS&C
# IP74          0   T&N&C ; D -> (T&N&S | T&N&C) ; A      CleanInS&C
# IP75          0           (T&N;S) | (T&N;C;D -> A)      CleanInS&C
# IP76          0        D->T;N;C;D->(T&N&S|T&N&C);A   SentinelFirst
# IP8           0                (S&T&N)|(C&T&N) ; A      CleanInS&C
# IP8           0                (S&T&N)|(C&T&N) ; A      CleanInS&C
# IP8           0                (S&T&N)|(C&T&N) ; A      CleanInS&C
# IP8           0                (S&T&N)|(C&T&N) ; A      CleanInS&C
# IP8           0                (S&T&N)|(C&T&N) ; A      CleanInS&C
# IP9           1       D -> (((T;N;C)|(T;N;S)) ; A)   SentinelFirst
#
#      Gen Category Repeat Computation Which Tasks?
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP1    SingleLoop                  n          all
# IP10   CleanFirst                  y          noD
# IP16   SingleLoop                  n         noDN
# IP27    CleanInSC                  n         noDN
# IP3    CleanFirst                  n          all
# IP33   CleanFirst                  n          noD
# IP46   CleanFirst                  n          all
# IP5    CleanFirst                  n          all
# IP5    CleanFirst                  n          all
# IP5    CleanFirst                  n          all
# IP5    CleanFirst                  n          all
# IP5    CleanFirst                  n          all
# ...           ...                ...          ...
# IP6    CleanFirst                  n          noD
# IP6    CleanFirst                  n          noD
# IP6    CleanFirst                  n          noD
# IP6    CleanFirst                  n          noD
# IP6    CleanFirst                  n          noD
# IP63   SingleLoop                  n          noD
# IP64   SingleLoop                  n          noN
# IP65   CleanFirst                  y          all
# IP65   CleanFirst                  y          all
# IP65   CleanFirst                  y          all
# IP65   CleanFirst                  y          all
# IP66    CleanInSC                  y          all
# IP67   CleanFirst                  n          all
# IP68    CleanInSC                  n          all
# IP69   SingleLoop                  n          all
# IP7     CleanInSC                  y          all
# IP70   CleanFirst                  n          all
# IP71   CleanFirst                  n          all
# IP72   CleanFirst                  y          all
# IP73    CleanInSC                  n          noD
# IP74    CleanInSC                  y          all
# IP74    CleanInSC                  y          all
# IP75    CleanInSC                  n          all
# IP76   CleanFirst                  y          all
# IP8     CleanInSC                  n          noD
# IP8     CleanInSC                  n          noD
# IP8     CleanInSC                  n          noD
# IP8     CleanInSC                  n          noD
# IP8     CleanInSC                  n          noD
# IP9    CleanFirst                  y          all
#
# [61 rows x 40 columns]

# %%
datasets = ['HS', 'T1', 'T1Acc', 'T2', 'T3Non']

# %%
dataset_config = {
    'T1': {
        'path': lambda id: f'{CODE_DIR}/T1/{id}.ml',
        'tokenizer': OCamlTokenizer
    },
    'T1Acc': {
        'path': lambda id: f'{CODE_DIR}/T1Acc/{id}/cs019-2013-rainfall/rainfall-program.current.arr',
        'tokenizer': PyretTokenizer
    }
}

# %%
def ingest_dataset(name):
    codes = read_and_join_coding(name)
    config = dataset_config[name]
    tokenizer = dataset_config[name]['tokenizer']()
    
    programs = []
    labels = []
    for _, entry in codes.iterrows():
        path = config['path'](entry.ID)
        try:
            src = open(path).read()
        except FileNotFoundError:
            continue
            
        general_label = GeneralRainfallLabels.from_string(entry['Gen Category'].strip())
        detailed_label = DetailedRainfallLabels.from_string(entry['Detail Category'].strip())
        
        try:
            list(tokenizer.tokenize(src))
        except TokenizerError as e:
            #print(e)
            #return
            continue
        
        programs.append(src)
        labels.append(general_label)
        
    return build_prelabeled_dataset(GeneralRainfallLabels, programs, labels, tokenizer)

# %%
for key in ['T1']:
    ds = ingest_dataset(key)
    ds.save(f'{REPO_DIR}/data/rainfall/{key}.pkl')
# Out:
# 100%|██████████| 44/44 [00:00<00:00, 166.69it/s]
